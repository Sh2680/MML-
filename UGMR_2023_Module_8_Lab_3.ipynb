# %% [markdown]
# <a href="https://colab.research.google.com/github/Sh2680/MML-/blob/main/UGMR_2023_Module_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 19:25:36--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json.1’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   159MB/s    in 0.4s
#
# 2024-03-31 19:25:36 (159 MB/s) - ‘arxiv-paper-data.json.1’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 12325  1711.08797v1  Hashing is a basic tool for dimensionality red...  stat
# 36252  1604.06710v1  Empirical game-theoretic analysis (EGTA) has r...    cs
# 9422   1708.02363v1  Recently software development companies starte...    cs
# 25345  1507.08373v1  Vectors of Locally Aggregated Descriptors (VLA...    cs
# 4175   1701.02870v3  We introduce an inference technique to produce...    cs
# ...             ...                                                ...   ...
# 11708  1610.03774v2  This work characterizes the benefits of averag...  stat
# 12254  1710.11029v2  Stochastic gradient descent (SGD) is widely be...    cs
# 4214   1708.06834v3  Recurrent Neural Networks (RNNs) continue to s...    cs
# 36703   1311.4180v3  In this paper we define Clinical Data Intellig...    cs
# 7832   1803.07102v1  Gaussian processes (GPs) are Bayesian nonparam...  stat
#
#                                                    title  year  \
# 12325  Practical Hash Functions for Similarity Estima...  2017
# 36252  Using Reinforcement Learning to Validate Empir...  2016
# 9422   Beyond the technical challenges for deploying ...  2017
# 25345                              When VLAD met Hilbert  2015
# 4175   Context-aware Captions from Context-agnostic S...  2017
# ...                                                  ...   ...
# 11708  Parallelizing Stochastic Approximation Through...  2016
# 12254  Stochastic gradient descent performs variation...  2017
# 4214   Skip RNN: Learning to Skip State Updates in Re...  2017
# 36703  Towards a New Science of a Clinical Data Intel...  2013
# 7832   Learning non-Gaussian Time Series using the Bo...  2018
#
#                                                 keywords
# 12325  [dimensionality, reduction, perfomance, assump...
# 36252  [empirical, theoretic, successfully, competing...
# 9422   [development, companies, techniques, introduci...
# 25345  [aggregated, descriptors, imagevideo, represen...
# 4175   [introduce, inference, technique, discriminati...
# ...                                                  ...
# 11708  [characterizes, averaging, techniques, conjunc...
# 12254  [stochastic, regularization, minimizes, potent...
# 4214   [recurrent, outstanding, performance, sequence...
# 36703  [intelligence, generated, improving, intellige...
# 7832   [processes, nonparametric, generative, interpr...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 12325    [dimensionality, reduction, perfomance, assump...
# 36252    [empirical, theoretic, successfully, competing...
# 9422     [development, companies, techniques, introduci...
# 25345    [aggregated, descriptors, imagevideo, represen...
# 4175     [introduce, inference, technique, discriminati...
#                                ...
# 8526     [obtaining, progression, treatment, monitoring...
# 7570     [cumulative, repeatedly, selecting, distributi...
# 32506    [recognition, techniques, industrial, commerci...
# 22864    [automatic, leverages, generative, modelling, ...
# 3643     [discussions, essential, organizing, conclaves...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8691 words.
# Out of those 4507 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="31943cba-0499-43bc-b903-8ad668a49f50" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("31943cba-0499-43bc-b903-8ad668a49f50")) {                    Plotly.newPlot(                        "31943cba-0499-43bc-b903-8ad668a49f50",                        [{"x":["synthetic","experiments","similarity","practical","comparison","permutation","concentration","estimation","guarantees","applications","tabulation","different","approximate","prominent","sufficiently","functions","assumption","experimental","classification","guaranteed","reduction","performance","neighbour","demonstrate","contribution","including","structured","dimensionality","guarantee","analytically","multiagent","negligible","simulated","typically","successfully","equilibria","effectiveness","simulator","reinforcement","empirical","environments","continuous","environment","competing","strategic","literature","equilibrium","theoretic","simulation","impossible","benchmark","integrated","developed","companies","deploying","challenged","automation","techniques","recommendation","investing","operations","introducing","maintenance","technical","practitioners","experience","challenges","stakeholders","experiences","decisions","departments","solutions","researched","development","engineers","personalisation","discusses","operation","industrial","behaviour","functionality","communicate","inception","stationary","pragmatic","influence","requested","requirement","aggregated","formulations","euclidean","framework","limitations","fundamental","nonlinear","approaches","recognition","efficiently","covariance","introduce","kernelized","classifiers","descriptors","accelerate","sophisticated","furthermore","properties","benefiting","restriction","outperform","imagevideo","inherently","challenging","aggregate","representations","captioning","semantically","outperforms","distinguishes","generative","particular","inference","describes","evaluations","discrimination","discriminative","justification","differences","supervision","technique","components","attribute","effectively","extensively","architectures","increasingly","qualitative","indicates","representation","attention","additional","information","mechanism","estimators","auxiliary","detections","component","critically","predictions","identification","carefully","localized","practices","following","architecture","programming","conditions","knowledge","approximately","parameter","prohibitively","processes","uncertainty","projected","approximation","simultaneous","clustering","algorithms","independently","submatrices","biclustering","alleviate","structure","multidimensional","algorithm","numerically","principal","hierarchical","associated","maintaining","estimating","comparing","construction","parameterizing","regularizer","generating","parameters","dimensions","estimated","represented","straightforward","distribution","estimator","propagation","ancestral","concentrates","transforming","activations","autoencoder","deterministic"],"y":[126,562,142,148,138,9,10,211,62,446,1,758,127,16,25,208,76,370,509,32,105,894,6,556,75,229,105,55,35,16,8,11,50,119,96,4,195,13,117,143,88,111,134,31,8,124,11,38,80,17,215,62,191,9,9,7,9,373,29,2,63,48,10,41,14,37,131,4,13,63,4,143,5,133,5,2,24,42,21,31,15,14,7,23,11,60,6,25,13,16,40,486,63,84,47,452,386,163,18,317,6,106,60,18,25,174,225,3,16,100,3,13,249,30,229,19,42,268,11,124,270,210,96,47,22,92,8,46,58,260,106,37,133,45,132,60,59,23,358,149,117,711,102,14,21,14,83,13,91,99,33,18,11,81,219,121,130,350,34,140,7,113,78,21,119,25,142,572,45,2,2,25,349,15,801,9,36,103,117,46,62,79,68,2,16,110,249,45,57,86,30,204,20,79,2,2,10,22,33,42],"type":"bar"},{"x":["synthetic","experiments","similarity","practical ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4507,), (4507, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8125

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Text</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Attentional</span> <span style='background-color:rgba(0, 255, 0, 0.5787234042553191);'>Convolutional</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>for</span> <span style=''>Scene</span> <span style=''>Text</span> <span style='background-color:rgba(0, 255, 0, 0.5148741418764302);'>Detection</span> <br/><br/><span style=''>Recent</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>models</span> <span style=''>have</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrated</span> <span style=''>strong</span> <span style='background-color:rgba(0, 255, 0, 0.393939393939394);'>capabilities</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.38235294117647056);'>classifying</span> <span style=''>text</span> <span style=''>and</span> <span style=''>non</span> <span style=''>text</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>components</span> <span style=''>in</span> <span style=''>natural</span> <span style=''>images</span> <span style=''>They</span> <span style=''>extract</span> <span style=''>a</span> <span style=''>high</span> <span style=''>level</span> <span style=''>feature</span> <span style=''>computed</span> <span style=''>globally</span> <span style=''>from</span> <span style=''>a</span> <span style=''>whole</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>component</span> <span style=''>(patch)</span> <span style=''>where</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.8333333333333333);'>cluttered</span> <span style='background-color:rgba(0, 255, 0, 0.6046511627906976);'>background</span> <span style='background-color:rgba(0, 255, 0, 0.33646616541353386);'>information</span> <span style=''>may</span> <span style=''>dominate</span> <span style=''>true</span> <span style=''>text</span> <span style=''>features</span> <span style=''>in</span> <span style=''>the</span> <span style=''>deep</span> <span style='background-color:rgba(0, 255, 0, 0.3822393822393822);'>representation</span> <span style=''>This</span> <span style=''>leads</span> <span style=''>to</span> <span style=''>less</span> <span style='background-color:rgba(0, 255, 0, 0.6428571428571428);'>discriminative</span> <span style=''>power</span> <span style=''>and</span> <span style=''>poorer</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>robustness</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>new</span> <span style=''>system</span> <span style=''>for</span> <span style=''>scene</span> <span style=''>text</span> <span style='background-color:rgba(0, 255, 0, 0.5148741418764302);'>detection</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>proposing</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>Text</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Attentional</span> <span style='background-color:rgba(0, 255, 0, 0.5787234042553191);'>Convolutional</span> <span style=''>Neural</span> <span style=''>Network</span> <span style=''>(Text</span> <span style=''>CNN)</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particularly</span> <span style=''>focuses</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.5121951219512194);'>extracting</span> <span style=''>text</span> <span style=''>related</span> <span style=''>regions</span> <span style=''>and</span> <span style=''>features</span> <span style=''>from</span> <span style=''>the</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>components</span> <span style=''>We</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>n ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Composing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>with</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>and</span> <span style=''>fast</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>general</span> <span style=''>modeling</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>that</span> <span style=''>composes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>with</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>methods</span> <span style=''>and</span> <span style=''>combines</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>respective</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>strengths</span> <span style=''>Our</span> <span style=''>model</span> <span style=''>family</span> <span style=''>augments</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>in</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>with</span> <span style=''>neural</span> <span style=''>network</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observation</span> <span style=''>models</span> <span style=''>For</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>we</span> <span style=''>extend</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>autoencoders</span> <span style=''>to</span> <span style=''>use</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recognition</span> <span style=''>networks</span> <span style=''>that</span> <span style=''>output</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conjugate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potentials</span> <span style=''>All</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>components</span> <span style=''>of</span> <span style=''>these</span> <span style=''>models</span> <span style=''>are</span> <span style=''>learned</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simultaneously</span> <span style=''>with</span> <span style=''>a</span> <span style=''>single</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>giving</span> <span style=''>a</span> <span style=''>scalable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>leverages</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>natural</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>gradients</span> <span style='background-color:rgba(0, 255, 0, 0.3);' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>DinTucker</span> <span style=''>Scaling</span> <span style=''>up</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>models</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multidimensional</span> <span style=''>arrays</span> <span style=''>with</span> <span style=''>billions</span> <span style=''>of</span> <span style=''>elements</span> <br/><br/><span style=''>Infinite</span> <span style=''>Tucker</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Decomposition</span> <span style=''>(InfTucker)</span> <span style=''>and</span> <span style=''>random</span> <span style=''>function</span> <span style=''>prior</span> <span style=''>models</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.7080291970802921);'>nonparametric</span> <span style=''>Bayesian</span> <span style=''>models</span> <span style=''>on</span> <span style=''>infinite</span> <span style='background-color:rgba(255, 0, 0, 0.6923076923076923);'>exchangeable</span> <span style=''>arrays</span> <span style=''>are</span> <span style=''>more</span> <span style=''>powerful</span> <span style=''>models</span> <span style=''>than</span> <span style=''>widely</span> <span style=''>used</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333326);'>multilinear</span> <span style='background-color:rgba(255, 0, 0, 0.509090909090909);'>factorization</span> <span style=''>methods</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style=''>Tucker</span> <span style=''>and</span> <span style=''>PARAFAC</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style=''>(partly)</span> <span style=''>due</span> <span style=''>to</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.5932203389830508);'>capability</span> <span style=''>of</span> <span style=''>modeling</span> <span style='background-color:rgba(255, 0, 0, 0.36486486486486486);'>nonlinear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relationships</span> <span style=''>between</span> <span style=''>array</span> <span style=''>elements</span> <span style=''>Despite</span> <span style=''>their</span> <span style=''>great</span> <span style='background-color:rgba(255, 0, 0, 0.5192307692307694);'>predictive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>and</span> <span style=''>sound</span> <span style='background-color:rgba(255, 0, 0, 0.31718061674008824);'>theoretical</span> <span style='background-color:rgba(0, 255, 0, 0.5454545454545454);'>foundations</span> <span style=''>they</span> <span style=''>cannot</span> <span style=''>handle</span> <span style=''>massive</span> <span style=''>data</span> <span style=''>due</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prohibitively</span> <span style=''>high</span> <span style=''>training</span> <span style=''>time</span> <span style=''>To</span> <span style=''>overcome</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3191489361702127);'>limitation</span> <span style=''>we</span> <span style=''>present</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Distributed</span> <span style=''>Infinite</span> <span style=''>Tucker</span> <span style=''>(DINTUCKER)</span> <span style=''>a</span> <span style=''>large</span> <span style=''>scale</span> <span style='background-color:rgba(255, 0, 0, 0.36486486486486486);'>nonlinear</span> <span style=''>tensor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>MAPREDUCE</span> <span style=''>While</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maintain ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>DIRT</span> <span style=''>T</span> <span style=''>Approach</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Unsupervised</span> <span style=''>Domain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Adaptation</span> <br/><br/><span style=''>Domain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adaptation</span> <span style=''>refers</span> <span style=''>to</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>leveraging</span> <span style=''>labeled</span> <span style=''>data</span> <span style=''>in</span> <span style=''>a</span> <span style=''>source</span> <span style=''>domain</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>an</span> <span style=''>accurate</span> <span style=''>model</span> <span style=''>in</span> <span style=''>a</span> <span style=''>target</span> <span style=''>domain</span> <span style=''>where</span> <span style=''>labels</span> <span style=''>are</span> <span style=''>scarce</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unavailable</span> <span style=''>A</span> <span style=''>recent</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>finding</span> <span style=''>a</span> <span style=''>common</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>two</span> <span style=''>domains</span> <span style=''>is</span> <span style=''>via</span> <span style=''>domain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversarial</span> <span style=''>training</span> <span style=''>(Ganin</span> <span style=''>Lempitsky</span> <span style=''>2015)</span> <span style=''>which</span> <span style=''>attempts</span> <span style=''>to</span> <span style=''>induce</span> <span style=''>a</span> <span style=''>feature</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extractor</span> <span style=''>that</span> <span style=''>matches</span> <span style=''>the</span> <span style=''>source</span> <span style=''>and</span> <span style=''>target</span> <span style=''>feature</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>in</span> <span style=''>some</span> <span style=''>feature</span> <span style=''>space</span> <span style=''>However</span> <span style=''>domain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversarial</span> <span style=''>training</span> <span style=''>faces</span> <span style=''>two</span> <span style=''>critical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>limitations</span> <span style=''>1)</span> <span style=''>if</span> <span style=''>the</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extraction</span> <span style=''>function</span> <span style=''>has</span> <span style=''>high</span> <span style=''>capacity</span> <span style=''>then</span> <span style=''>feature</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>matching</span> <span style=''>is</span> <span style=''>a</span> <span style=''>weak</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraint</span> <span style=''>2)</span> <span style=''>in</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conservative</span> <span style=''>domain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adaptation</span> <span style=''>(where</span> <span style=''>no</span> <span style=''>single</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>can</span> <span style=''>perform</span> <span style=''>well</span> <span style=''>in</span> <span style=''>both</span> <span style=''>the</span> <span style=''> ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.09759598134194475)
# 	representation (0.1284535342662361)
# 	segmentation (0.06817366343738787)
# 	knowledge (0.12558306422676713)
# 	experimental (0.13275923932543954)
# 	detection (0.11876569788302835)
# 	information (0.25511302475780406)
# 	different (0.2719770362396842)
# 	convolutional (0.13311804808037317)
# 	recognition (0.13850017940437748)
#
# Some Statistics words are:
# 	theoretical (0.14853452558370592)
# 	variables (0.1425732737208147)
# 	statistical (0.15449577744659712)
# 	estimation (0.17536015896671633)
# 	stochastic (0.14605067064083457)
# 	algorithm (0.3969200198708395)
# 	distribution (0.18877297565822157)
# 	dimensional (0.18777943368107303)
# 	inference (0.20417287630402384)
# 	regression (0.18281172379533037)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d7a49395-2b69-46a0-b746-3fcece70634e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d7a49395-2b69-46a0-b746-3fcece70634e")) {                    Plotly.newPlot(                        "d7a49395-2b69-46a0-b746-3fcece70634e",                        [{"x":["synthetic","experiments","similarity","practical","comparison","permutation","concentration","estimation","guarantees","applications","tabulation","different","approximate","prominent","sufficiently","functions","assumption","experimental","classification","guaranteed","reduction","performance","neighbour","demonstrate","contribution","including","structured","dimensionality","guarantee","analytically","multiagent","negligible","simulated","typically","successfully","equilibria","effectiveness","simulator","reinforcement","empirical","environments","continuous","environment","competing","strategic","literature","equilibrium","theoretic","simulation","impossible","benchmark","integrated","developed","companies","deploying","challenged","automation","techniques","recommendation","investing","operations","introducing","maintenance","technical","practitioners","experience","challenges","stakeholders","experiences","decisions","departments","solutions","researched","development","engineers","personalisation","discusses","operation","industrial","behaviour","functionality","communicate","inception","stationary","pragmatic","influence","requested","requirement","aggregated","formulations","euclidean","framework","limitations","fundamental","nonlinear","approaches","recognition","efficiently","covariance","introduce","kernelized","classifiers","descriptors","accelerate","sophisticated","furthermore","properties","benefiting","restriction","outperform","imagevideo","inherently","challenging","aggregate","representations","captioning","semantically","outperforms","distinguishes","generative","particular","inference","describes","evaluations","discrimination","discriminative","justification","differences","supervision","technique","components","attribute","effectively","extensively","architectures","increasingly","qualitative","indicates","representation","attention","additional","information","mechanism","estimators","auxiliary","detections","component","critically","predictions","identification","carefully","localized","practices","following","architecture","programming","conditions","knowledge","approximately","parameter","prohibitively","processes","uncertainty","projected","approximation","simultaneous","clustering","algorithms","independently","submatrices","biclustering","alleviate","structure","multidimensional","algorithm","numerically","principal","hierarchical","associated","maintaining","estimating","comparing","construction","parameterizing","regularizer","generating","parameters","dimensions","estimated","represented","straightforward","distribution","estimator","propagation","ancestral","concentrates","transforming","activations","autoencoder","deterministic","factorizes","probability","parametric","autoencoders","challenge","objective","likelihood","difficult","reconstruction","rewritten","gradually","optimizing","parametrized","correlated","favourably","investigating","universality","probabilistic","corresponding","unrelated","identical","correlation","canonical","established","variability","identified","evaluates","responses","completely","considered","conditioned","connected","computational","variables","intermediate","intractable","characterization","combination","perspective","polynomial","unbounded","relationship","intractability","populated","borderline","tractable","collapses","complexity","instances","important","otherwise","theoretical","parameterised" ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	rewritten
# 	ingenious
# 	blockmodel
# 	percolation
# 	connectome
# 	terabytes
# 	robustification
# 	minimizers
# 	confounders
# 	katehakis
# 	seasonality
# 	california
# 	unmeasured
# 	penalization
# 	manufacturability
# 	distributionally
# 	followers
# 	absolutely
# 	ellipsoid
# 	emphstructured
# Some words which never appear in Statistics papers:
# 	investing
# 	stakeholders
# 	personalisation
# 	requested
# 	benefiting
# 	imagevideo
# 	submatrices
# 	biclustering
# 	populated
# 	determinism
# 	compilation
# 	compiling
# 	propagators
# 	visualising
# 	preprocessed
# 	installed
# 	rewriting
# 	axiomatization
# 	recognizes
# 	hemisphere

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0886122864996764e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7725
